# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarpattnaik8080/SalesPipelineinSaaS/blob/main/SalesPipelinesinIndianStartups.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df=pd.read_csv("Sales_Pipeline_SaaS_Startup.csv")

# %%
df
# Out:
#      Opportunity ID           Technology\nPrimary       City  \
# 0         N00000001            ERP Implementation  Bengaluru
# 1         N00000002            ERP Implementation      Delhi
# 2         N00000003  Technical Business Solutions      Delhi
# 3         N00000004  Technical Business Solutions     Mumbai
# 4         N00000005            ERP Implementation      Delhi
# ...             ...                           ...        ...
# 8205      N00008206            ERP Implementation      Delhi
# 8206      N00008207            ERP Implementation     Mumbai
# 8207      N00008208  Technical Business Solutions     Mumbai
# 8208      N00008209            ERP Implementation  Bengaluru
# 8209      N00008210            ERP Implementation     Mumbai
#
#         B2B Sales Medium  Sales Velocity Opportunity Status  \
# 0              Marketing            76.0                Won
# 1     Enterprise Sellers            63.0               Loss
# ...

# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8210 entries, 0 to 8209
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Opportunity ID                  8210 non-null   object
#  1   Technology
# Primary              8210 non-null   object
#  2   City                            8210 non-null   object
#  3   B2B Sales Medium                8210 non-null   object
#  4   Sales Velocity                  8209 non-null   float64
#  5   Opportunity Status              8209 non-null   object
#  6   Sales Stage Iterations          8209 non-null   float64
#  7   Opportunity Size (USD)          8209 non-null   float64
#  8   Client Revenue Sizing           8209 non-null   object
#  9   Client Employee Sizing          8209 non-null   object
#  10  Business from Client Last Year  8209 non-null   object
#  11  Compete Intel                   8209 non-null   object
# ...

# %%
#to know the numbers of rows and columns
df.shape #8210 rows and 13 columns
# Out:
# (8210, 13)

# %%
df
# Out:
#      Opportunity ID           Technology\nPrimary       City  \
# 0         N00000001            ERP Implementation  Bengaluru
# 1         N00000002            ERP Implementation      Delhi
# 2         N00000003  Technical Business Solutions      Delhi
# 3         N00000004  Technical Business Solutions     Mumbai
# 4         N00000005            ERP Implementation      Delhi
# ...             ...                           ...        ...
# 8205      N00008206            ERP Implementation      Delhi
# 8206      N00008207            ERP Implementation     Mumbai
# 8207      N00008208  Technical Business Solutions     Mumbai
# 8208      N00008209            ERP Implementation  Bengaluru
# 8209      N00008210            ERP Implementation     Mumbai
#
#         B2B Sales Medium  Sales Velocity Opportunity Status  \
# 0              Marketing            76.0                Won
# 1     Enterprise Sellers            63.0               Loss
# ...

# %%
#counting the unique values in the City column
df.City.value_counts()
# Out:
# Mumbai       3972
# Delhi        2556
# Bengaluru    1682
# Name: City, dtype: int64

# %%
#specifying the column name i wnat to use by making a dictionary
new_columns={
   "Tech":"Technology Primary",
    "Sales":"B2B Sales Medium",
    "Revenue":"Client Revenue Sizing",
    "Employeesize":"Client Employee Sizing"
}
#Renaming the columns to a specified column names
df.rename(new_columns,axis=1,inplace=True)

# %%
new_columns
# Out:
# {'Tech': 'Technology Primary',
#  'Sales': 'B2B Sales Medium',
#  'Revenue': 'Client Revenue Sizing',
#  'Employeesize': 'Client Employee Sizing'}
